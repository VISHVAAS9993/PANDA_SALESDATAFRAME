# %%
import pandas as pd,numpy as np,seaborn as sns

# %%
dfs = pd.read_csv(r'C:\Users\user\Downloads\Sales_Data.csv')
dfs
# Out:
#                                  Region               Country   Item_Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda    Baby Food
# 1     Central America and the Caribbean                Panama      Snacks
# 2                                Europe        Czech Republic   Beverages
# 3                                  Asia           North Korea      Cereal
# 4                                  Asia             Sri Lanka      Snacks
# ...                                 ...                   ...         ...
# 4995              Australia and Oceania           New Zealand   Household
# 4996       Middle East and North Africa            Azerbaijan     Clothes
# 4997                               Asia               Myanmar   Baby Food
# 4998                             Europe               Finland     Clothes
# 4999                 Sub-Saharan Africa              Tanzania  Vegetables
#
#      Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# 0           Online              M  12/20/2013  957081544.0  01-11-2014
# 1          Offline              C  07-05-2010  301644504.0   7/26/2010
# 2          Offline              C  09-12-2011  478051030.0   9/29/2011
# 3          Offline              L   5/13/2010  892599952.0   6/15/2010
# 4          Offline              C   7/20/2015  571902596.0   7/27/2015
# ...            ...            ...         ...          ...         ...
# 4995       Offline              C  04-03-2015  217984473.0   4/20/2015
# 4996       Offline              L   8/17/2014  169748055.0  10-02-2014
# 4997       Offline              H  11/23/2016          NaN  12-10-2016
# 4998        Online              L   4/22/2014          NaN  05-11-2014
# 4999        Online              L  07-08-2011          NaN  08-07-2011
#
#       Units_Sold  Unit_SellingPrice  Unit_MakingCost  Total_Revenue  \
# 0            552             255.28           159.42      140914.56
# 1           2167             152.58            97.44      330640.86
# 2           4778              47.45            31.79      226716.10
# 3           9016             205.70           117.11     1854591.20
# 4           7542             152.58            97.44     1150758.36
# ...          ...                ...              ...            ...
# 4995        5305             668.27           502.54     3545172.35
# 4996        1077             109.28            35.84      117694.56
# 4997        5204             255.28           159.42     1328477.12
# 4998        9410             109.28            35.84     1028324.80
# 4999        2450             154.06            90.93      377447.00
#
#       Total_Cost  Total_Profit
# 0       87999.84      52914.72
# 1      211152.48     119488.38
# 2      151892.62      74823.48
# 3     1055863.76     798727.44
# 4      734892.48     415865.88
# ...          ...           ...
# 4995  2665974.70     879197.65
# 4996    38599.68      79094.88
# 4997   829621.68     498855.44
# 4998   337254.40     691070.40
# 4999   222778.50     154668.50
#
# [5000 rows x 14 columns]

# %% [markdown]
# # Groupby
# syntax: pd.groupby([colName/s])[col/s_we_inrested_in].function()

# %%
dfs.isnull().sum()
# Out:
# Region                0
# Country               0
# Item_Type            11
# Sales_Channel         0
# Order_Priority        0
# Order_Date            0
# Order_ID              3
# Ship_Date             0
# Units_Sold            0
# Unit_SellingPrice     0
# Unit_MakingCost       0
# Total_Revenue         0
# Total_Cost            0
# Total_Profit          0
# dtype: int64

# %%
dfs = dfs.dropna()
dfs
# Out:
#                                  Region               Country  Item_Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1     Central America and the Caribbean                Panama     Snacks
# 2                                Europe        Czech Republic  Beverages
# 3                                  Asia           North Korea     Cereal
# 4                                  Asia             Sri Lanka     Snacks
# ...                                 ...                   ...        ...
# 4992       Middle East and North Africa                  Iran    Clothes
# 4993                             Europe               Denmark    Clothes
# 4994                 Sub-Saharan Africa               Liberia  Cosmetics
# 4995              Australia and Oceania           New Zealand  Household
# 4996       Middle East and North Africa            Azerbaijan    Clothes
#
#      Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# 0           Online              M  12/20/2013  957081544.0  01-11-2014
# 1          Offline              C  07-05-2010  301644504.0   7/26/2010
# 2          Offline              C  09-12-2011  478051030.0   9/29/2011
# 3          Offline              L   5/13/2010  892599952.0   6/15/2010
# 4          Offline              C   7/20/2015  571902596.0   7/27/2015
# ...            ...            ...         ...          ...         ...
# 4992       Offline              L  07-11-2014  927583253.0   8/30/2014
# 4993       Offline              H  05-09-2012  713357150.0  06-03-2012
# 4994       Offline              M   6/17/2012  374724614.0   6/23/2012
# 4995       Offline              C  04-03-2015  217984473.0   4/20/2015
# 4996       Offline              L   8/17/2014  169748055.0  10-02-2014
#
#       Units_Sold  Unit_SellingPrice  Unit_MakingCost  Total_Revenue  \
# 0            552             255.28           159.42      140914.56
# 1           2167             152.58            97.44      330640.86
# 2           4778              47.45            31.79      226716.10
# 3           9016             205.70           117.11     1854591.20
# 4           7542             152.58            97.44     1150758.36
# ...          ...                ...              ...            ...
# 4992        1352             109.28            35.84      147746.56
# 4993        7088             109.28            35.84      774576.64
# 4994        8195             437.20           263.33     3582854.00
# 4995        5305             668.27           502.54     3545172.35
# 4996        1077             109.28            35.84      117694.56
#
#       Total_Cost  Total_Profit
# 0       87999.84      52914.72
# 1      211152.48     119488.38
# 2      151892.62      74823.48
# 3     1055863.76     798727.44
# 4      734892.48     415865.88
# ...          ...           ...
# 4992    48455.68      99290.88
# 4993   254033.92     520542.72
# 4994  2157989.35    1424864.65
# 4995  2665974.70     879197.65
# 4996    38599.68      79094.88
#
# [4986 rows x 14 columns]

# %%
dfs.isnull().sum()
# Out:
# Region               0
# Country              0
# Item_Type            0
# Sales_Channel        0
# Order_Priority       0
# Order_Date           0
# Order_ID             0
# Ship_Date            0
# Units_Sold           0
# Unit_SellingPrice    0
# Unit_MakingCost      0
# Total_Revenue        0
# Total_Cost           0
# Total_Profit         0
# dtype: int64

# %%
# reset the index
dfs.reset_index(drop=True,inplace=True)
dfs.sample()
# Out:
#                                 Region             Country  Item_Type  \
# 915  Central America and the Caribbean  Dominican Republic  Household
#
#     Sales_Channel Order_Priority Order_Date     Order_ID   Ship_Date  \
# 915       Offline              L  3/19/2016  810593879.0  04-01-2016
#
#      Units_Sold  Unit_SellingPrice  Unit_MakingCost  Total_Revenue  \
# 915        1597             668.27           502.54     1067227.19
#
#      Total_Cost  Total_Profit
# 915   802556.38     264670.81

# %%
dfs.columns
# Out:
# Index(['Region', 'Country', 'Item_Type', 'Sales_Channel', 'Order_Priority',
#        'Order_Date', 'Order_ID', 'Ship_Date', 'Units_Sold',
#        'Unit_SellingPrice', 'Unit_MakingCost', 'Total_Revenue', 'Total_Cost',
#        'Total_Profit'],
#       dtype='object')

# %%
# groupby
dfs.groupby('Region')['Total_Profit'].sum()
# Out:
# Region
# Asia                                 2.755281e+08
# Australia and Oceania                1.749346e+08
# Central America and the Caribbean    2.046120e+08
# Europe                               5.005781e+08
# Middle East and North Africa         2.312263e+08
# North America                        4.124040e+07
# Sub-Saharan Africa                   5.308692e+08
# Name: Total_Profit, dtype: float64

# %%
dfs.groupby('Region')

# %%
dfs.groupby('Region')['Total_Profit']

# %%
dfs.groupby('Region')['Total_Profit'].count()
# Out:
# Region
# Asia                                  712
# Australia and Oceania                 416
# Central America and the Caribbean     534
# Europe                               1327
# Middle East and North Africa          608
# North America                         106
# Sub-Saharan Africa                   1283
# Name: Total_Profit, dtype: int64

# %%
dfs.groupby('Region')['Total_Profit'].count()/(len(dfs))*100
# Out:
# Region
# Asia                                 14.279984
# Australia and Oceania                 8.343361
# Central America and the Caribbean    10.709988
# Europe                               26.614521
# Middle East and North Africa         12.194144
# North America                         2.125953
# Sub-Saharan Africa                   25.732050
# Name: Total_Profit, dtype: float64

# %%
dfs.groupby('Region')['Total_Profit'].count().plot(kind = 'pie')
# Out:
# <Axes: ylabel='Total_Profit'>

# %%
# grouping 2 or more that two 
dfs.groupby(['Region','Country'])['Total_Revenue'].mean()
# Out:
# Region              Country
# Asia                Bangladesh    1.223867e+06
#                     Bhutan        1.189964e+06
#                     Brunei        1.165347e+06
#                     Cambodia      1.047818e+06
#                     China         1.088718e+06
#                                       ...
# Sub-Saharan Africa  The Gambia    1.831741e+06
#                     Togo          1.213865e+06
#                     Uganda        1.457174e+06
#                     Zambia        1.373677e+06
#                     Zimbabwe      1.088932e+06
# Name: Total_Revenue, Length: 185, dtype: float64

# %%
dfs.groupby(['Region','Country'])['Total_Revenue','Total_Profit'].mean()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8012\2378658535.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   dfs.groupby(['Region','Country'])['Total_Revenue','Total_Profit'].mean()
#                                Total_Revenue   Total_Profit
# Region             Country
# Asia               Bangladesh   1.223867e+06  401111.847727
#                    Bhutan       1.189964e+06  361293.314667
#                    Brunei       1.165347e+06  339521.942647
#                    Cambodia     1.047818e+06  361831.399600
#                    China        1.088718e+06  354057.315926
# ...                                      ...            ...
# Sub-Saharan Africa The Gambia   1.831741e+06  448556.615263
#                    Togo         1.213865e+06  330953.330000
#                    Uganda       1.457174e+06  398329.991364
#                    Zambia       1.373677e+06  354489.316774
#                    Zimbabwe     1.088932e+06  332153.008571
#
# [185 rows x 2 columns]

# %%
pd.crosstab(index= [dfs['Region'],dfs['Country']],
             columns = dfs['Sales_Channel'],
             values = dfs['Units_Sold'],
             aggfunc = [np.max,np.min,np.mean])
# Out:
#                                  amax           amin                mean  \
# Sales_Channel                 Offline Online Offline Online      Offline
# Region             Country
# Asia               Bangladesh    9585   8175     182    300  5290.222222
#                    Bhutan        9811   9274    1252    585  4842.000000
#                    Brunei        9854   9737      73      2  4068.117647
#                    Cambodia      9438   9721    1332    848  5549.272727
#                    China         7762   9823    1404     59  4844.000000
# ...                               ...    ...     ...    ...          ...
# Sub-Saharan Africa The Gambia    9449   9214     146    282  4792.545455
#                    Togo          9234   9919     674     84  4765.500000
#                    Uganda        9762   8291    1160    162  5512.933333
#                    Zambia        9975   9296      69    194  5199.687500
#                    Zimbabwe      8136   9647      59    667  3830.692308
#
#
# Sales_Channel                       Online
# Region             Country
# Asia               Bangladesh  3479.846154
#                    Bhutan      5172.800000
#                    Brunei      4116.823529
#                    Cambodia    4613.928571
#                    China       3922.375000
# ...                                    ...
# Sub-Saharan Africa The Gambia  4934.000000
#                    Togo        4638.875000
#                    Uganda      4351.285714
#                    Zambia      3762.666667
#                    Zimbabwe    5513.375000
#
# [185 rows x 6 columns]

# %%
pd.crosstab(index= [dfs['Region'],dfs['Country']],
             columns = dfs['Sales_Channel'],
             values = dfs['Unit_SellingPrice'],
             aggfunc = [np.max,np.min,np.mean])
# Out:
#                                  amax            amin                mean  \
# Sales_Channel                 Offline  Online Offline  Online     Offline
# Region             Country
# Asia               Bangladesh  668.27  437.20   47.45    9.33  346.503333
#                    Bhutan      651.21  668.27    9.33    9.33  247.253333
#                    Brunei      651.21  668.27    9.33    9.33  198.640000
#                    Cambodia    668.27  668.27   47.45    9.33  277.768182
#                    China       668.27  668.27    9.33    9.33  232.418182
# ...                               ...     ...     ...     ...         ...
# Sub-Saharan Africa The Gambia  668.27  668.27    9.33   47.45  310.965455
#                    Togo        668.27  651.21    9.33    9.33  340.237143
#                    Uganda      651.21  668.27    9.33  154.06  244.078667
#                    Zambia      668.27  668.27   47.45   47.45  254.839375
#                    Zimbabwe    668.27  205.70   47.45    9.33  251.515385
#
#
# Sales_Channel                      Online
# Region             Country
# Asia               Bangladesh  225.225385
#                    Bhutan      243.481333
#                    Brunei      274.364118
#                    Cambodia    222.285000
#                    China       276.843125
# ...                                   ...
# Sub-Saharan Africa The Gambia  363.277500
#                    Togo        199.446875
#                    Uganda      450.397143
#                    Zambia      353.684667
#                    Zimbabwe    136.456250
#
# [185 rows x 6 columns]

# %%
pd.crosstab(index= dfs['Region'],
             columns = dfs['Sales_Channel'],
             values = dfs['Unit_SellingPrice'],
             aggfunc = ['count']).plot(kind='bar')
# Out:
# <Axes: xlabel='Region'>

# %%
pd.crosstab(index= dfs['Region'],
             columns = dfs['Item_Type'],
             values = dfs['Unit_MakingCost'],
             aggfunc = ['count'])
# Out:
#                                       count                           \
# Item_Type                         Baby Food Beverages Cereal Clothes
# Region
# Asia                                     62        73     61      59
# Australia and Oceania                    37        42     34      32
# Central America and the Caribbean        43        47     45      40
# Europe                                  112       121    102     104
# Middle East and North Africa             58        43     47      55
# North America                             7        13      6       5
# Sub-Saharan Africa                      125       107     89      89
#
#                                                                    \
# Item_Type                         Cosmetics Fruits Household Meat
# Region
# Asia                                     59     74        64   54
# Australia and Oceania                    39     30        38   30
# Central America and the Caribbean        40     48        43   55
# Europe                                  114    112        97  111
# Middle East and North Africa             47     60        56   44
# North America                            10      9        14    5
# Sub-Saharan Africa                      114    114       111  100
#
#                                                                         \
# Item_Type                         Office Supplies Personal Care Snacks
# Region
# Asia                                           48            57     57
# Australia and Oceania                          42            27     33
# Central America and the Caribbean              36            38     47
# Europe                                        123           114    103
# Middle East and North Africa                   42            58     47
# North America                                  12             9      9
# Sub-Saharan Africa                            115           110    101
#
#
# Item_Type                         Vegetables
# Region
# Asia                                      44
# Australia and Oceania                     32
# Central America and the Caribbean         52
# Europe                                   114
# Middle East and North Africa              51
# North America                              7
# Sub-Saharan Africa                       108

# %%
dfs.head()
# Out:
#                               Region               Country  Item_Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1  Central America and the Caribbean                Panama     Snacks
# 2                             Europe        Czech Republic  Beverages
# 3                               Asia           North Korea     Cereal
# 4                               Asia             Sri Lanka     Snacks
#
#   Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# 0        Online              M  12/20/2013  957081544.0  01-11-2014
# 1       Offline              C  07-05-2010  301644504.0   7/26/2010
# 2       Offline              C  09-12-2011  478051030.0   9/29/2011
# 3       Offline              L   5/13/2010  892599952.0   6/15/2010
# 4       Offline              C   7/20/2015  571902596.0   7/27/2015
#
#    Units_Sold  Unit_SellingPrice  Unit_MakingCost  Total_Revenue  Total_Cost  \
# 0         552             255.28           159.42      140914.56    87999.84
# 1        2167             152.58            97.44      330640.86   211152.48
# 2        4778              47.45            31.79      226716.10   151892.62
# 3        9016             205.70           117.11     1854591.20  1055863.76
# 4        7542             152.58            97.44     1150758.36   734892.48
#
#    Total_Profit
# 0      52914.72
# 1     119488.38
# 2      74823.48
# 3     798727.44
# 4     415865.88

# %%
dfs.shape # rows n columns
# Out:
# (5000, 14)

# %%
dfs.columns
# Out:
# Index(['Region', 'Country', 'Item_Type', 'Sales_Channel', 'Order_Priority',
#        'Order_Date', 'Order_ID', 'Ship_Date', 'Units_Sold',
#        'Unit_SellingPrice', 'Unit_MakingCost', 'Total_Revenue', 'Total_Cost',
#        'Total_Profit'],
#       dtype='object')

# %%
dfs.groupby(['Region','Sales_Channel'])['Units_Sold'].count()
# Out:
# Region                             Sales_Channel
# Asia                               Offline          339
#                                    Online           380
# Australia and Oceania              Offline          222
#                                    Online           194
# Central America and the Caribbean  Offline          271
#                                    Online           263
# Europe                             Offline          667
#                                    Online           663
# Middle East and North Africa       Offline          312
#                                    Online           298
# North America                      Offline           59
#                                    Online            47
# Sub-Saharan Africa                 Offline          634
#                                    Online           651
# Name: Units_Sold, dtype: int64

# %%
pd.crosstab(index = dfs['Region'],
            columns = dfs['Sales_Channel'],
            values = dfs['Units_Sold'],
            aggfunc = ['count'])
# Out:
#                                     count
# Sales_Channel                     Offline Online
# Region
# Asia                                  339    380
# Australia and Oceania                 222    194
# Central America and the Caribbean     271    263
# Europe                                667    663
# Middle East and North Africa          312    298
# North America                          59     47
# Sub-Saharan Africa                    634    651

# %%
pd.crosstab(index = dfs['Region'],
            columns = dfs['Sales_Channel'],
            values = dfs['Units_Sold'],
            aggfunc = ['count']).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Region'>

# %% [markdown]
# # insights:
# * From the above data we can see that most of people from Europe has more number of people of sales_channel of both online and ofline
#
# * The North America has less number of Sales_Channel of both online and ofline
#
# * The total number of respondends are 5000 online is 2540 and ofline is 2496 the little bit high is offline
#
# * From the above data there no na values the total respondance will be placed
#
#  * here we can see the graph between Europe and Sub-Saharan Africa we can observe there nort more difference

# %%
df['Item_Type'].unique()

# %%
pd.crosstab(index = df['Region'],
            columns = df['Item_Type'] == 'Cosmetics',
            values = df['Total_Profit'],
            aggfunc = [np.mean,np.max])

# %%
pd.crosstab(index = df['Region'],
            columns = df['Item_Type'] == 'Cosmetics',
            values = df['Total_Profit'],
            aggfunc = [np.mean]).plot(kind = 'bar')

# %% [markdown]
# # insights:
# *  above data we can see that on which region the iteam_type is cosmetics of total_profit mean values
#
# * on above data most of the people were use cosmetics it is define bye true we can see in graph
#
# * the highest mean of the cosmetics occurs in Australia and Oceania will average most of sales of cosmetics and the median of this region is higher than other so we says that from these will get high profit
#
# * when compare to other region theNorth America mean and median little less so this region will get little bit less profit on averagly
#
# * finally we know that the cosmetics are heavy sales in every region the graphs says that the True value is more high than false value
#
# * in Every region cosmetics have high demand and high sales and get high profits

# %%
df.columns

# %%
df.head(1)

# %%
df['Item_Type'].unique()

# %%
pd.crosstab(index = df['Region'],
            columns = df['Item_Type'],
            values = df['Total_Profit'],
            aggfunc=[np.mean])

# %% [markdown]
# # insights:
# * In Asia the Household iteam_type got more profit it place a high avarage value when compare to another iteams and least profit will got on fruits iteam_type.
#
# * In Australia and Oceania the Cosmetics iteam_type got more profit it place a high avarage value when compare to another iteams and least profit will got on fruits iteam_type.
#
# * In Central America and the Caribbean the Cosmetics iteam_type got more profit it place a high avarage value when compare to another iteams and least profit will got on fruits iteam_type.
#
# * In Europe the Cosmetics iteam_type got more profit it place a high avarage value when compare to another iteams and least profit will got on fruits iteam_type.
#
# * In Middle East and North Africa the Cosmetics iteam_type got more profit it place a high avarage value when compare to another iteams and least profit will got on fruits iteam_type.
#
# * In North America the Household iteam_type got more profit it place a high avarage value when compare to another iteams and least profit will got on fruits iteam_type.
#
# * In Sub-Saharan Africa the Household iteam_type got more profit it place a high avarage value when compare to another iteams and least profit will got on fruits iteam_type.
#
# * The oveall review of data we can observe that the fruits will get less profit in every region and the hight profit will occurs at Cosmetics and Household.
